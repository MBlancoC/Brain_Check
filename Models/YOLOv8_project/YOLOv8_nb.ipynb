# %%
# prompt: then code the line to mount to my drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/YOLOv8_project/Dataset_yolo/TRAIN_CROP'
# Out:
# NO  YES

# %%
data_dir ='/content/drive/My Drive/YOLOv8_project/Dataset_yolo/TRAIN_CROP'
data_yaml = '/content/drive/My Drive/YOLOv8_project/Dataset_yolo/train.yaml'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.8/677.8 kB 6.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os

#import model
model = YOLO('yolov8n.pt')

#train model
results = model.train(data=data_yaml, epochs=5)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 82.5MB/s]
# Ultralytics YOLOv8.0.235 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...
