# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
PATH = "/content/gdrive/MyDrive/Datasets/"

# %% [markdown]
# Github Dataset

# %%
import zipfile

# %%
with zipfile.ZipFile("/content/gdrive/MyDrive/Datasets/no.zip", 'r') as zip_ref:
    zip_ref.extractall('/content/github_dataset2')

# %%
with zipfile.ZipFile("/content/gdrive/MyDrive/Datasets/yes.zip", 'r') as zip_ref:
    zip_ref.extractall('/content/github_dataset2')

# %%
import os
from IPython.display import Image, display

#yes, no, brain_tumor_dataset
folder_path = '/content/github_dataset2/no'
files = os.listdir(folder_path)

print("Archivos encontrados:", files)
print(f"cantidad de imagenes: {len(files)}")  # Imprimir los archivos encontrados

count = 0
for file in files:
    if file.lower().endswith(('.png', '.jpg', '.jpeg')):
        print("Mostrando:", file)  # Imprimir el nombre del archivo que se va a mostrar
        display(Image(filename=os.path.join(folder_path, file)))
        count += 1
        if count == 5:
            break

if count == 0:
    print("No se encontraron imágenes para mostrar.")
# Out:
# Archivos encontrados: ['no492.jpg', 'no1079.jpg', 'no1396.jpg', 'no1093.jpg', 'no1219.jpg', 'no1387.jpg', 'no1087.jpg', 'no173.jpg', 'no1250.jpg', 'no1490.jpg', 'no1181.jpg', 'no1266.jpg', 'no420.jpg', 'no1230.jpg', 'no1058.jpg', 'no1428.jpg', 'no1432.jpg', 'no1039.jpg', 'no1236.jpg', 'no1457.jpg', 'no510.jpg', 'no486.jpg', 'no144.jpg', 'no1086.jpg', 'no1133.jpg', 'no1315.jpg', 'no494.jpg', 'no1291.jpg', 'no0.jpg', 'no547.jpg', 'no246.jpg', 'no260.jpg', 'no1194.jpg', 'no1333.jpg', 'no1028.jpg', 'no1109.jpg', 'no52.jpg', 'no141.jpg', 'no1497.jpg', 'no518.jpg', 'no24.jpg', 'no498.jpg', 'no1310.jpg', 'no1149.jpg', 'no1023.jpg', 'no136.jpg', 'no293.jpg', 'no159.jpg', 'no1047.jpg', 'no301.jpg', 'no1418.jpg', 'no1386.jpg', 'no248.jpg', 'no1462.jpg', 'no318.jpg', 'no1382.jpg', 'no527.jpg', 'no1193.jpg', 'no1474.jpg', 'no536.jpg', 'no226.jpg', 'no192.jpg', 'no1381.jpg', 'no1065.jpg', 'no1239.jpg', 'no1145.jpg', 'no43.jpg', 'no316.jpg', 'no1281.jpg', 'no1298.jpg', 'no1105.jpg', 'no1111.jpg', 'no1406.jpg', 'no100.jpg', 'no1277.jpg', 'no361.jpg', 'no1285.jpg', 'no324.jpg', 'no1404.jpg', 'no1268.jpg', 'no328.jpg', 'no1110.jpg', 'no1185.jpg', 'no1453.jpg', 'no1183.jpg', 'no189.jpg', 'no1244.jpg', 'no131.jpg', 'no1247.jpg', 'no211.jpg', 'no1160.jpg', 'no1442.jpg', 'no1349.jpg', 'no1431.jpg', 'no167.jpg', 'no1388.jpg', 'no1292.jpg', 'no359.jpg', 'no378.jpg', 'no1357.jpg', 'no431.jpg', 'no1
257.jpg', 'no177.jpg', 'no384.jpg', 'no412.jpg', 'no1484.jpg', 'no117.jpg', 'no1141.jpg', 'no1324.jpg', 'no168.jpg', 'no1129.jpg', 'no1112.jpg', 'no1027.jpg', 'no1248.jpg', 'no207.jpg', 'no337.jpg', 'no1229.jpg', 'no1100.jpg', 'no546.jpg', 'no1020.jpg', 'no1364.jpg', 'no229.jpg', 'no1415.jpg', 'no419.jpg', 'no1454.jpg', 'no1220.jpg', 'no1214.jpg', 'no35.jpg', 'no1465.jpg', 'no1309.jpg', 'no1345.jpg', 'no121.jpg', 'no1204.jpg', 'no110.jpg', 'no122.jpg', 'no529.jpg', 'no135.jpg', 'no452.jpg', 'no382.jpg', 'no228.jpg', 'no1452.jpg' ...
# cantidad de imagenes: 1000
# Mostrando: no492.jpg
# Mostrando: no1079.jpg
# Mostrando: no1396.jpg
# Mostrando: no1093.jpg
# Mostrando: no1219.jpg

# %%
import os
from IPython.display import Image, display

#yes, no, brain_tumor_dataset
folder_path = '/content/github_dataset2/yes'
files = os.listdir(folder_path)

print("Archivos encontrados:", files)
print(f"cantidad de imagenes: {len(files)}")  # Imprimir los archivos encontrados

count = 0
for file in files:
    if file.lower().endswith(('.png', '.jpg', '.jpeg')):
        print("Mostrando:", file)  # Imprimir el nombre del archivo que se va a mostrar
        display(Image(filename=os.path.join(folder_path, file)))
        count += 1
        if count == 5:
            break

if count == 0:
    print("No se encontraron imágenes para mostrar.")
# Out:
# Archivos encontrados: ['y1207.jpg', 'y1088.jpg', 'y1382.jpg', 'y245.jpg', 'y1238.jpg', 'y1425.jpg', 'y336.jpg', 'y519.jpg', 'y166.jpg', 'y1098.jpg', 'y474.jpg', 'y1374.jpg', 'y1375.jpg', 'y1200.jpg', 'y1256.jpg', 'y1211.jpg', 'y479.jpg', 'y1320.jpg', 'y529.jpg', 'y1467.jpg', 'y105.jpg', 'y386.jpg', 'y10.jpg', 'y286.jpg', 'y126.jpg', 'y1470.jpg', 'y1010.jpg', 'y122.jpg', 'y1204.jpg', 'y1245.jpg', 'y103.jpg', 'y352.jpg', 'y462.jpg', 'y1129.jpg', 'y395.jpg', 'y150.jpg', 'y444.jpg', 'y401.jpg', 'y461.jpg', 'y1051.jpg', 'y189.jpg', 'y1468.jpg', 'y1193.jpg', 'y1126.jpg', 'y1397.jpg', 'y1412.jpg', 'y1150.jpg', 'y226.jpg', 'y1431.jpg', 'y1248.jpg', 'y465.jpg', 'y1333.jpg', 'y1300.jpg', 'y13.jpg', 'y1358.jpg', 'y32.jpg', 'y1183.jpg', 'y1326.jpg', 'y333.jpg', 'y204.jpg', 'y1240.jpg', 'y282.jpg', 'y158.jpg', 'y1175.jpg', 'y1262.jpg', 'y409.jpg', 'y1172.jpg', 'y268.jpg', 'y316.jpg', 'y1249.jpg', 'y1399.jpg', 'y266.jpg', 'y1196.jpg', 'y1087.jpg', 'y228.
 'y1298.jpg', 'y315.jpg', 'y1008.jpg', 'y1411.jpg', 'y175.jpg', 'y359.jpg', 'y34.jpg', 'y148.jpg', 'y1234.jpg', 'y478.jpg', 'y464.jpg', 'y1392.jpg', 'y149.jpg', 'y476.jpg', 'y1276.jpg', 'y232.jpg', 'y238.jpg', 'y1120.jpg', 'y1327.jpg', 'y168.jpg', 'y1301.jpg', 'y120.jpg', 'y217.jpg', 'y418.jpg', 'y375.jpg', 'y1004.jpg', 'y296.jpg', 'y198.jpg', 'y538.jpg', 'y341.jpg', 'y179.jpg', 'y1306.jpg', 'y1188.jpg', 'y1105.jpg', 'y1199.jpg', 'y1346.jpg', 'y1186.jpg', 'y537.jpg', 'y1362.jpg', 'y1102.jpg', 'y182.jpg', 'y319.jpg', 'y142.jpg', 'y1433.jpg', 'y1381.jpg', 'y1341.jpg', 'y1094.jpg', 'y1003.jpg', 'y143.jpg', 'y1056.jpg', 'y0.jpg', 'y1423.jpg', 'y324.jpg', 'y139.jpg', 'y274.jpg', 'y117.jpg', 'y1140.jpg', 'y108.jpg', 'y1223.jpg', 'y25.jpg', 'y1185.jpg', 'y1477.jpg', 'y1133.jpg', 'y1233.jpg', 'y307.jpg', 'y370.jpg', 'y547.jpg', 'y1041.jpg', 'y1308.jpg', 'y299.jpg', 'y355.jpg', 'y210.jpg', 'y1261.jpg', 'y106.jpg', 'y428.jpg', 'y374.jpg', 'y335.jpg', 'y127.jpg', 'y1479.jpg', 'y1070.jpg', 'y531.jpg', 'y133.jpg', 'y457.jpg', 'y1243.jpg', 'y454.jpg', 'y187.jpg', 'y1090.jpg', 'y536.jpg', 'y224.jpg', 'y1038.jpg', 'y1107.jpg', 'y12 ...
# cantidad de imagenes: 1000
# Mostrando: y1207.jpg
# Mostrando: y1088.jpg
# Mostrando: y1382.jpg
# Mostrando: y245.jpg
# Mostrando: y1238.jpg

# %% [markdown]
# Kaggle Dataset

# %% [markdown]
# Github Dataset

# %%
github_path = '/content/github_dataset2'

# %%
import cv2
import imutils
import numpy as np

# %%
def crop_imgs(set_name, add_pixels_value=0):
    """
    Finds the extreme points on the image and crops the rectangular out of them
    """
    set_new = []
    for img in set_name:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        gray = cv2.GaussianBlur(gray, (5, 5), 0)

        # threshold the image, then perform a series of erosions +
        # dilations to remove any small regions of noise
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)

        # find contours in thresholded image, then grab the largest one
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)

        # find the extreme points
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])

        ADD_PIXELS = add_pixels_value
        new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
        set_new.append(new_img)

    return np.array(set_new)

# %%
img = cv2.imread('/content/github_dataset2/yes/y1207.jpg')
IMG_SIZE = (224,224)
img = cv2.resize(
            img,
            dsize=IMG_SIZE,
            interpolation=cv2.INTER_CUBIC
        )
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray = cv2.GaussianBlur(gray, (5, 5), 0)

# threshold the image, then perform a series of erosions +
# dilations to remove any small regions of noise
thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
thresh = cv2.erode(thresh, None, iterations=2)
thresh = cv2.dilate(thresh, None, iterations=2)

# find contours in thresholded image, then grab the largest one
cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
c = max(cnts, key=cv2.contourArea)

# find the extreme points
extLeft = tuple(c[c[:, :, 0].argmin()][0])
extRight = tuple(c[c[:, :, 0].argmax()][0])
extTop = tuple(c[c[:, :, 1].argmin()][0])
extBot = tuple(c[c[:, :, 1].argmax()][0])

# add contour on the image
img_cnt = cv2.drawContours(img.copy(), [c], -1, (0, 255, 255), 4)

# add extreme points
img_pnt = cv2.circle(img_cnt.copy(), extLeft, 8, (0, 0, 255), -1)
img_pnt = cv2.circle(img_pnt, extRight, 8, (0, 255, 0), -1)
img_pnt = cv2.circle(img_pnt, extTop, 8, (255, 0, 0), -1)
img_pnt = cv2.circle(img_pnt, extBot, 8, (255, 255, 0), -1)

# crop
ADD_PIXELS = 0
new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,6))
plt.subplot(141)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.title('Step 1. Get the original image')
plt.subplot(142)
plt.imshow(img_cnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 2. Find the biggest contour')
plt.subplot(143)
plt.imshow(img_pnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 3. Find the extreme points')
plt.subplot(144)
plt.imshow(new_img)
plt.xticks([])
plt.yticks([])
plt.title('Step 4. Crop the image')
plt.show()

# %%
from IPython.display import clear_output
# !apt-get install tree
clear_output()
# create new folders
# !mkdir TRAIN TEST VAL TRAIN/YES TRAIN/NO TEST/YES TEST/NO VAL/YES VAL/NO
# !tree -d
# Out:
# .
# ├── carpeta_yolo_v1
# │   ├── test
# │   │   ├── images
# │   │   └── labels
# │   ├── train
# │   │   ├── images
# │   │   └── labels
# │   └── valid
# │       ├── images
# │       └── labels
# ├── gdrive
# │   └── MyDrive
# │       ├── Colab Notebooks
# │       └── Datasets
# ├── mi_carpeta_descomprimida
# │   ├── brain_tumor_dataset
# │   │   ├── no
# │   │   └── yes
# │   ├── no
# │   └── yes
# ├── no_dataset_github
# │   └── no
# ├── sample_data
# ├── TEST
# │   ├── NO
# │   └── YES
# ├── TRAIN
# │   ├── NO
# │   └── YES
# ├── VAL
# │   ├── NO
# │   └── YES
# └── yes_dataset_github
#     └── yes
#
# 34 directories

# %%
import os
import shutil

# Ruta del directorio que contiene las imágenes
IMG_PATH = '/content/github_dataset2/'

# División de los datos en entrenamiento, validación y prueba
for CLASS in os.listdir(IMG_PATH):
    if not CLASS.startswith('.'):
        IMG_NUM = len(os.listdir(IMG_PATH + CLASS))
        for (n, FILE_NAME) in enumerate(os.listdir(IMG_PATH + CLASS)):
            img = IMG_PATH + CLASS + '/' + FILE_NAME
            if n < 0.05 * IMG_NUM:  # Primeros 5% para TEST
                shutil.copy(img, 'TEST/' + CLASS.upper() + '/' + FILE_NAME)
            elif n < 0.80 * IMG_NUM:  # Siguientes hasta el 80% para TRAIN
                shutil.copy(img, 'TRAIN/'+ CLASS.upper() + '/' + FILE_NAME)
            else: #restante 20%
                shutil.copy(img, 'VAL/'+ CLASS.upper() + '/' + FILE_NAME)

# %%
from tqdm import tqdm

def load_data(dir_path, img_size=(100,100)):
    """
    Load resized images as np.arrays to workspace
    """
    X = []
    y = []
    i = 0
    labels = dict()
    for path in tqdm(sorted(os.listdir(dir_path))):
        if not path.startswith('.'):
            labels[i] = path
            for file in os.listdir(dir_path + path):
                if not file.startswith('.'):
                    img = cv2.imread(dir_path + path + '/' + file)
                    X.append(img)
                    y.append(i)
            i += 1
    X = np.array(X)
    y = np.array(y)
    print(f'{len(X)} images loaded from {dir_path} directory.')
    return X, y, labels

# %%
TRAIN_DIR = 'TRAIN/'
TEST_DIR = 'TEST/'
VAL_DIR = 'VAL/'
IMG_SIZE = (224,224)

# use predefined function to load the image data into workspace
X_train, y_train, labels = load_data(TRAIN_DIR, IMG_SIZE)
X_test, y_test, _ = load_data(TEST_DIR, IMG_SIZE)
X_val, y_val, _ = load_data(VAL_DIR, IMG_SIZE)
# Out:
# 100%|██████████| 2/2 [00:04<00:00,  2.16s/it]
# <ipython-input-47-1933a8b41adb>:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.array(X)
# 1500 images loaded from TRAIN/ directory.
# 100%|██████████| 2/2 [00:00<00:00, 10.59it/s]
# 100 images loaded from TEST/ directory.
# 100%|██████████| 2/2 [00:00<00:00,  2.12it/s]
# 400 images loaded from VAL/ directory.

# %%
labels
# Out:
# {0: 'NO', 1: 'YES'}

# %%
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools

y = dict()
y[0] = []
y[1] = []
for set_name in (y_train, y_val, y_test):
    y[0].append(np.sum(set_name == 0))
    y[1].append(np.sum(set_name == 1))

trace0 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[0],
    name='No',
    marker=dict(color='#33cc33'),
    opacity=0.7
)
trace1 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[1],
    name='Yes',
    marker=dict(color='#ff3300'),
    opacity=0.7
)
data = [trace0, trace1]
layout = go.Layout(
    title='Count of classes in each set',
    xaxis={'title': 'Set'},
    yaxis={'title': 'Count'}
)
fig = go.Figure(data, layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5d427ae6-3a98-493f-aea2-83cf28bb715e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d427ae6-3a98-493f-aea2-83cf28bb715e")) {                    Plotly.newPlot(                        "5d427ae6-3a98-493f-aea2-83cf28bb715e",                        [{"marker":{"color":"#33cc33"},"name":"No","opacity":0.7,"x":["Train Set","Validation Set","Test Set"],"y":[750,200,50],"type":"bar"},{"marker":{"color":"#ff3300"},"name":"Yes","opacity":0.7,"x":["Train Set","Validation Set","Test Set"],"y":[750,200,50],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{ ...

# %%
RATIO_LIST = []
for set in (X_train, X_test, X_val):
    for img in set:
        RATIO_LIST.append(img.shape[1]/img.shape[0])

plt.hist(RATIO_LIST)
plt.title('Distribution of Image Ratios')
plt.xlabel('Ratio Value')
plt.ylabel('Count')
plt.show()

# %%
# apply this for each set
X_train_crop = crop_imgs(set_name=X_train)
X_val_crop = crop_imgs(set_name=X_val)
X_test_crop = crop_imgs(set_name=X_test)
# Out:
# <ipython-input-42-65876982ba26>:31: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
print(f"cantidad de imagenes: {len(X_train_crop)}")
print(f"cantidad de imagenes: {len(X_val_crop)}")
print(f"cantidad de imagenes: {len(X_test_crop)}")
# Out:
# cantidad de imagenes: 1500
# cantidad de imagenes: 400
# cantidad de imagenes: 100

# %%
RATIO_LIST2 = []
for set in (X_train_crop, X_test_crop, X_val_crop):
    for img in set:
        RATIO_LIST2.append(img.shape[1]/img.shape[0])

plt.hist(RATIO_LIST2)
plt.title('Distribution of Image Ratios')
plt.xlabel('Ratio Value')
plt.ylabel('Count')
plt.show()

# %%
def plot_samples(X, y, labels_dict, n=50):
    """
    Creates a gridplot for desired number of images (n) from the specified set
    """
    for index in range(len(labels_dict)):
        imgs = X[np.argwhere(y == index)][:n]
        j = 10
        i = int(n/j)

        plt.figure(figsize=(15,6))
        c = 1
        for img in imgs:
            plt.subplot(i,j,c)
            plt.imshow(img[0])

            plt.xticks([])
            plt.yticks([])
            c += 1
        plt.suptitle('Tumor: {}'.format(labels_dict[index]))
        plt.show()

plot_samples(X_train_crop, y_train, labels, 30)

# %%
def save_new_images(x_set, y_set, folder_name):
    i = 0
    for (img, imclass) in zip(x_set, y_set):
        if imclass == 0:
            cv2.imwrite(folder_name+'NO/'+str(i)+'.jpg', img)
        else:
            cv2.imwrite(folder_name+'YES/'+str(i)+'.jpg', img)
        i += 1

# %%
# saving new images to the folder
# !mkdir TRAIN_CROP TEST_CROP VAL_CROP TRAIN_CROP/YES TRAIN_CROP/NO TEST_CROP/YES TEST_CROP/NO VAL_CROP/YES VAL_CROP/NO

save_new_images(X_train_crop, y_train, folder_name='TRAIN_CROP/')
save_new_images(X_val_crop, y_val, folder_name='VAL_CROP/')
save_new_images(X_test_crop, y_test, folder_name='TEST_CROP/')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp -r TRAIN_CROP "/content/gdrive/MyDrive/Datasets/"

# %%
# !cp -r TEST_CROP "/content/gdrive/MyDrive/Datasets/"

# %%
# !cp -r VAL_CROP "/content/gdrive/MyDrive/Datasets/"

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16, preprocess_input
from keras import layers
from keras.models import Model, Sequential
from keras.optimizers import Adam, RMSprop
from keras.callbacks import EarlyStopping

# %%
def preprocess_imgs(set_name, img_size):
    """
    Resize and apply VGG-15 preprocessing
    """
    set_new = []
    for img in set_name:
        img = cv2.resize(
            img,
            dsize=img_size,
            interpolation=cv2.INTER_CUBIC
        )
        set_new.append(preprocess_input(img))
    return np.array(set_new)

# %%
X_train_prep = preprocess_imgs(set_name=X_train_crop, img_size=IMG_SIZE)
X_test_prep = preprocess_imgs(set_name=X_test_crop, img_size=IMG_SIZE)
X_val_prep = preprocess_imgs(set_name=X_val_crop, img_size=IMG_SIZE)

# %%
plot_samples(X_train_prep, y_train, labels, 30)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
