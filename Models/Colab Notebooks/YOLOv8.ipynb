# %%
from google.colab import drive
drive.mount('/content/gdrive')

TRAIN_CROP = "/content/gdrive/MyDrive/Datasets/TRAIN_CROP"
TEST_CROP = "/content/gdrive/MyDrive/Datasets/TEST_CROP"
VAL_CROP = "/content/gdrive/MyDrive/Datasets/VAL_CROP"
# Out:
# Mounted at /content/gdrive

# %%
import os

# List files in the TRAIN_CROP directory
train_files = os.listdir(TRAIN_CROP)
print("Training set files:", train_files)

# List files in the TEST_CROP directory
test_files = os.listdir(TEST_CROP)
print("Test set files:", test_files)

# List files in the VAL_CROP directory
val_files = os.listdir(VAL_CROP)
print("Validation set files:", val_files)
# Out:
# Training set files: ['YES', 'NO']
# Test set files: ['YES', 'NO']
# Validation set files: ['YES', 'NO']

# %%
#Display some of the images from the data set TRAIN + NO
from IPython.display import Image, display

#yes, no, brain_tumor_dataset
files = os.listdir(TRAIN_CROP + "/NO")

print("Archivos encontrados:", files)
print(f"cantidad de imagenes: {len(files)}")  # Imprimir los archivos encontrados

count = 0
for file in files:
    if file.lower().endswith(('.png', '.jpg', '.jpeg')):
        print("Mostrando:", file)  # Imprimir el nombre del archivo que se va a mostrar
        display(Image(filename=os.path.join(TRAIN_CROP + "/NO", file)))
        count += 1
        if count == 5:
            break

if count == 0:
    print("No se encontraron imágenes para mostrar.")
# Out:
# Archivos encontrados: ['0.jpg', '1.jpg', '4.jpg', '3.jpg', '2.jpg', '5.jpg', '7.jpg', '6.jpg', '8.jpg', '9.jpg', '10.jpg', '11.jpg', '13.jpg', '12.jpg', '14.jpg', '15.jpg', '16.jpg', '17.jpg', '20.jpg', '18.jpg', '19.jpg', '23.jpg', '24.jpg', '25.jpg', '28.jpg', '21.jpg', '29.jpg', '30.jpg', '31.jpg', '33.jpg', '36.jpg', '35.jpg', '34.jpg', '32.jpg', '37.jpg', '38.jpg', '39.jpg', '40.jpg', '41.jpg', '46.jpg', '43.jpg', '42.jpg', '44.jpg', '45.jpg', '49.jpg', '48.jpg', '50.jpg', '51.jpg', '52.jpg', '53.jpg', '57.jpg', '58.jpg', '56.jpg', '55.jpg', '54.jpg', '60.jpg', '59.jpg', '61.jpg', '62.jpg', '63.jpg', '64.jpg', '65.jpg', '66.jpg', '68.jpg', '67.jpg', '69.jpg', '70.jpg', '71.jpg', '72.jpg', '75.jpg', '74.jpg', '76.jpg', '73.jpg', '77.jpg', '78.jpg', '79.jpg', '81.jpg', '80.jpg', '82.jpg', '84.jpg', '86.jpg', '83.jpg', '87.jpg', '88.jpg', '85.jpg', '89.jpg', '90.jpg', '91.jpg', '92.jpg', '94.jpg', '96.jpg', '99.jpg', '95.jpg', '100.jpg', '98.jpg', '97.jpg', '101.jpg', '102.jpg', '1
# ...
